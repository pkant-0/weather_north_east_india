# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import missingno as msno

# %%
df = pd.read_csv("D:\\weather\\weather_north_east_india\\NE-India-Rainfall-act-dep_1901_to_2019_0.csv")

# %%
df.head()
# Out:
#    YEAR    JUN    JUL    AUG    SEP  JUN-SEPT
# 0  1901  271.2  331.1  404.0  258.9    1265.2
# 1  1902  312.6  438.2  337.7  372.9    1461.4
# 2  1903  345.8  249.4  411.8  273.7    1280.7
# 3  1904  321.3  452.6  372.6  198.4    1344.9
# 4  1905  235.4  446.7  484.2  316.2    1482.5

# %%
df.count()
# Out:
# YEAR        119
# JUN         119
# JUL         119
# AUG         119
# SEP         119
# JUN-SEPT    119
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   YEAR      119 non-null    int64
#  1   JUN       119 non-null    float64
#  2   JUL       119 non-null    float64
#  3   AUG       119 non-null    float64
#  4   SEP       119 non-null    float64
#  5   JUN-SEPT  119 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 5.7 KB

# %%
df.columns
# Out:
# Index(['YEAR', 'JUN', 'JUL', 'AUG', 'SEP', 'JUN-SEPT'], dtype='object')

# %%
msno.matrix(df)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming df is already defined and is a DataFrame
plt.figure(figsize=(6, 4))
sns.heatmap(
    df.isnull(),
    cmap='inferno',
    cbar=False,
    yticklabels=False
)

plt.title('HeatMap of Missing: Weather_Data')
plt.show()

# %%
df.describe()
# Out:
#               YEAR         JUN         JUL         AUG         SEP  \
# count   119.000000  119.000000  119.000000  119.000000  119.000000
# mean   1960.000000  371.986555  444.115966  379.218487  295.731933
# std      34.496377   82.197469   86.966429   75.274176   63.097046
# min    1901.000000  197.300000  249.400000  216.300000  176.000000
# 25%    1930.500000  319.950000  379.100000  322.800000  246.950000
# 50%    1960.000000  363.900000  441.500000  373.800000  293.100000
# 75%    1989.500000  424.150000  506.100000  419.700000  340.100000
# max    2019.000000  638.900000  756.500000  595.700000  471.700000
#
#           JUN-SEPT
# count   119.000000
# mean   1491.060504
# std     200.481115
# min    1078.900000
# 25%    1345.150000
# 50%    1486.800000
# 75%    1639.200000
# max    2090.300000

# %%
df.shape
# Out:
# (119, 6)

# %%
df.isnull().sum()
# Out:
# YEAR        0
# JUN         0
# JUL         0
# AUG         0
# SEP         0
# JUN-SEPT    0
# dtype: int64

# %%
list = df.hist(bins=6, figsize=(15, 15))
plt.savefig("Histo,png")
